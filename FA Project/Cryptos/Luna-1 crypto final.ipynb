# %%
import pandas as pd
import numpy as np
import keras
import tensorflow as tf
from keras.preprocessing.sequence import TimeseriesGenerator
import plotly.graph_objs as go

# %%
filename = "LUNA1-USD.csv"
df = pd.read_csv(filename)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       731 non-null    object
#  1   Open       731 non-null    float64
#  2   High       731 non-null    float64
#  3   Low        731 non-null    float64
#  4   Close      731 non-null    float64
#  5   Adj Close  731 non-null    float64
#  6   Volume     731 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 40.1+ KB
# None

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_axis(df['Date'], inplace=True)
df.drop(columns=['Open', 'High', 'Low', 'Volume'], inplace=True)

# %%
close_data = df['Close'].values
close_data = close_data.reshape((-1,1))

split_percent = 0.80
split = int(split_percent*len(close_data))

close_train = close_data[:split]
close_test = close_data[split:]

date_train = df['Date'][:split]
date_test = df['Date'][split:]

print(len(close_train))
print(len(close_test))
# Out:
# 584
# 147

# %%
look_back = 10

train_generator = TimeseriesGenerator(close_train, close_train, length=look_back, batch_size=20)     
test_generator = TimeseriesGenerator(close_test, close_test, length=look_back, batch_size=1)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense

model = Sequential()
model.add(
    LSTM(units = 50,return_sequences = True,
        activation='relu',
        input_shape=(look_back,1))
)

model.add(
    LSTM(30,
        activation='relu',
        input_shape=(look_back,1), return_sequences = True)
)

model.add(
    LSTM(10,
        activation='relu',
        input_shape=(look_back,1))
)

model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

num_epochs = 50
model.fit(train_generator, epochs=num_epochs, verbose=1)
# Out:
# Epoch 1/50
# 29/29 [==============================] - 3s 8ms/step - loss: 32.9702
# Epoch 2/50
# 29/29 [==============================] - 0s 7ms/step - loss: 13.3273
# Epoch 3/50
# 29/29 [==============================] - 0s 7ms/step - loss: 9.9118
# Epoch 4/50
# 29/29 [==============================] - 0s 7ms/step - loss: 7.4365
# Epoch 5/50
# 29/29 [==============================] - 0s 8ms/step - loss: 9.7197
# Epoch 6/50
# 29/29 [==============================] - 0s 7ms/step - loss: 10.1663
# Epoch 7/50
# 29/29 [==============================] - 0s 7ms/step - loss: 3.8335
# Epoch 8/50
# 29/29 [==============================] - 0s 7ms/step - loss: 2.7119
# Epoch 9/50
# 29/29 [==============================] - 0s 7ms/step - loss: 2.3979
# Epoch 10/50
# 29/29 [==============================] - 0s 7ms/step - loss: 2.5445
# Epoch 11/50
# 29/29 [==============================] - 0s 7ms/step - loss: 1.5768
# Epoch 12/50
# 29/29 [==============================] - 0s 7ms/step - loss: 1.5719
# Epoch 13/50
# 29/29 [==============================] - 0s 8ms/step - loss: 1.5158
# Epoch 14/50
# 29/29 [==============================] - 0s 8ms/step - loss: 1.6879
# Epoch 15/50
# 29/29 [==============================] - 0s 8ms/step - loss: 1.2043
# Epoch 16/50
# 29/29 [==============================] - 0s 8ms/step - loss: 0.6840
# Epoch 17/50
# 29/29 [==============================] - 0s 8ms/step - loss: 1.3850
# Epoch 18/50
# 29/29 [==============================] - 0s 8ms/step - loss: 1.4131
# Epoch 19/50
# 29/29 [==============================] - 0s 8ms/step - loss: 1.1066
# Epoch 20/50
# 29/29 [==============================] - 0s 8ms/step - loss: 1.1549
# Epoch 21/50
# 29/29 [==============================] - 0s 7ms/step - loss: 0.9876
# Epoch 22/50
# 29/29 [==============================] - 0s 7ms/step - loss: 0.8375
# Epoch 23/50
# 29/29 [==============================] - 0s 7ms/step - loss: 1.2694
# Epoch 24/50
# 29/29 [==============================] - 0s 7ms/step - loss: 1.0217
# Epoch 25/50
# 29/29 [==============================] - 0s 8ms/step - loss: 0.6861
# Epoch 26/50
# 29/29 [==============================] - 0s 7ms/step - loss: 4.6704
# Epoch 27/50
# 29/29 [==============================] - 0s 7ms/step - loss: 5.5325
# Epoch 28/50
# 29/29 [==============================] - 0s 7ms/step - loss: 3.3444
# Epoch 29/50
# 29/29 [==============================] - 0s 7ms/step - loss: 2.1848
# Epoch 30/50
# 29/29 [==============================] - 0s 7ms/step - loss: 2.0952
# Epoch 31/50
# 29/29 [==============================] - 0s 7ms/step - loss: 1.8217
# Epoch 32/50
# 29/29 [==============================] - 0s 7ms/step - loss: 1.2106
# Epoch 33/50
# 29/29 [==============================] - 0s 7ms/step - loss: 1.3971
# Epoch 34/50
# 29/29 [==============================] - 0s 7ms/step - loss: 1.5154
# Epoch 35/50
# 29/29 [==============================] - 0s 7ms/step - loss: 1.5569
# Epoch 36/50
# 29/29 [==============================] - 0s 7ms/step - loss: 1.1106
# Epoch 37/50
# 29/29 [==============================] - 0s 7ms/step - loss: 0.9984
# Epoch 38/50
# 29/29 [==============================] - 0s 7ms/step - loss: 0.8594
# Epoch 39/50
# 29/29 [==============================] - 0s 8ms/step - loss: 0.5849
# Epoch 40/50
# 29/29 [==============================] - 0s 7ms/step - loss: 0.5741
# Epoch 41/50
# 29/29 [==============================] - 0s 7ms/step - loss: 0.5859
# Epoch 42/50
# 29/29 [==============================] - 0s 7ms/step - loss: 0.5157
# Epoch 43/50
# 29/29 [==============================] - 0s 7ms/step - loss: 0.7587
# Epoch 44/50
# 29/29 [==============================] - 0s 7ms/step - loss: 1.2634
# Epoch 45/50
# 29/29 [==============================] - 0s 7ms/step - loss: 1.6670
# Epoch 46/50
# 29/29 [==============================] - 0s 7ms/step - loss: 2.6028
# Epoch 47/50
# 29/29 [==============================] - 0s 7ms/step - loss: 1.4135
# Epoch 48/50
# 29/29 [==============================] - 0s 10ms/step - loss: 1.0771
# Epoch 49/50
# 29/29 [==============================] - 0s 9ms/step - loss: 1.7969
# Epoch 50/50
# 29/29 [==============================] - 0s 7ms/step - loss: 1.3444

# %%
prediction = model.predict(test_generator)

close_train = close_train.reshape((-1))
close_test = close_test.reshape((-1))
prediction = prediction.reshape((-1))

trace1 = go.Scatter(
    x = date_train,
    y = close_train,
    mode = 'lines',
    name = 'Data'
)
trace2 = go.Scatter(
    x = date_test,
    y = prediction,
    mode = 'lines',
    name = 'Prediction'
)
trace3 = go.Scatter(
    x = date_test,
    y = close_test,
    mode='lines',
    name = 'Ground Truth'
)
layout = go.Layout(
    title = "Google Stock",
    xaxis = {'title' : "Date"},
    yaxis = {'title' : "Close"}
)
fig = go.Figure(data=[trace1, trace2, trace3], layout=layout)
fig.show()
# Out:
# <div>                            <div id="225dc416-cc76-40d8-8db2-f5f82b9c4a0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("225dc416-cc76-40d8-8db2-f5f82b9c4a0c")) {                    Plotly.newPlot(                        "225dc416-cc76-40d8-8db2-f5f82b9c4a0c",                        [{"mode":"lines","name":"Data","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-19T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-15T00:00:00","2020-02-16T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-22T00:00:00","2020-02-23T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-02-29T00:00:00","2020-03-01T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-15T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-18T00:00:00","2020-04-19T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-25T00:00:00","2020-04-26T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-02T00:00:00","2020-05-03T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-09T00:00:00","2020-05-10T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-16T00:00:00","2020-05-17T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-23T00:00:00","2020-05-24T00:00:00","2020-05-25T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-05-30T00:00:00","2020-05-31T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2 ...

# %%
close_data = close_data.reshape((-1))
look_back = 10
def predict(num_prediction, model):
    prediction_list = close_data[-look_back:]
    
    for _ in range(num_prediction):
        x = prediction_list[-look_back:]
        x = x.reshape((1, look_back, 1))
        out = model.predict(x)[0][0]
        prediction_list = np.append(prediction_list, out)
    prediction_list = prediction_list[look_back-1:]
        
    return prediction_list
    
def predict_dates(num_prediction):
    last_date = df['Date'].values[-1]
    prediction_dates = pd.date_range(last_date, periods=num_prediction+1).tolist()
    return prediction_dates

num_prediction = 30
forecast = predict(num_prediction, model)
forecast_dates = predict_dates(num_prediction)

# %%
close_train = close_train.reshape((-1))
close_test = close_test.reshape((-1))
prediction = forecast.reshape((-1))

trace1 = go.Scatter(
    x = forecast_dates,
    y = close_train,
    mode = 'lines',
    name = 'Data'
)
trace2 = go.Scatter(
    x = forecast_dates,
    y = prediction,
    mode = 'lines',
    name = 'Prediction'
)
trace3 = go.Scatter(
    x = date_test,
    y = close_test,
    mode='lines',
    name = 'Ground Truth'
)
layout = go.Layout(
    title = "Google Stock",
    xaxis = {'title' : "Date"},
    yaxis = {'title' : "Close"}
)
fig = go.Figure(data=[trace2, trace3], layout=layout)
fig.show()
# Out:
# <div>                            <div id="dc2effcc-a4d8-4c78-a821-4b706dd49aa7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc2effcc-a4d8-4c78-a821-4b706dd49aa7")) {                    Plotly.newPlot(                        "dc2effcc-a4d8-4c78-a821-4b706dd49aa7",                        [{"mode":"lines","name":"Prediction","x":["2021-12-31T00:00:00","2022-01-01T00:00:00","2022-01-02T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-08T00:00:00","2022-01-09T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-15T00:00:00","2022-01-16T00:00:00","2022-01-17T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-22T00:00:00","2022-01-23T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-29T00:00:00","2022-01-30T00:00:00"],"y":[85.472542,85.96412658691406,87.70093536376953,87.68408966064453,87.51366424560547,86.0794677734375,83.0828857421875,81.45450592041016,81.09528350830078,81.28103637695312,81.24595642089844,81.2214126586914,81.15631866455078,80.60478210449219,79.87631225585938,78.82147979736328,77.69371795654297,77.01083374023438,76.66943359375,76.3979721069336,76.0406494140625,75.64839935302734,75.17012023925781,74.565673828125,73.90461730957031,73.20545959472656,72.56517028808594,72.05718231201172,71.62359619140625,71.18409729003906,70.71036529541016],"type":"scatter"},{"mode":"lines","name":"Ground Truth","x":["2021-08-07T00:00:00","2021-08-08T00:00:00","2021-08-09T00:00:00","2021-08-10T00:00:00","2021-08-11T00:00:00","2021-08-12T00:00:00","2021-08-13T00:00:00","2021-08-14T00:00:00","2021-08-15T00:00:00","2021-08-16T00:00:00","2021-08-17T00:00:00","2021-08-18T00:00:00","2021-08-19T00:00:00","2021-08-20T00:00:00","2021-08-21T00:00:00","2021-08-22T00:00:00","2021-08-23T00:00:00","2021-08-24T00:00:00","2021-08-25T00:00:00","2021-08-26T00:00:00","2021-08-27T00:00:00","2021-08-28T00:00:00","2021-08-29T00:00:00","2021-08-30T00:00:00","2021-08-31T00:00:00","2021-09-01T00:00:00","2021-09-02T00:00:00","2021-09-03T00:00:00","2021-09-04T00:00:00","2021-09-05T00:00:00","2021-09-06T00:00:00","2021-09-07T00:00:00","2021-09-08T00:00:00","2021-09-09T00:00:00","2021-09-10T00:00:00","2021-09-11T00:00:00","2021-09-12T00:00:00","2021-09-13T00:00:00","2021-09-14T00:00:00","2021-09-15T00:00:00","2021-09-16T00:00:00","2021-09-17T00:00:00","2021-09-18T00:00:00","2021-09-19T00:00:00","2021-09-20T00:00:00","2021-09-21T00:00:00","2021-09-22T00:00:00","2021-09-23T00:00:00","2021-09-24T00:00:00","2021-09-25T00:00:00","2021-09-26T00:00:00","2021-09-27T00:00:00","2021-09-28T00:00:00","2021-09-29T00:00:00","2021-09-30T00:00:00","2021-10-01T00:00:00","2021-10-02T00:00:00","2021-10-03T00:00:00","2021-10-04T00:00:00","2021-10-05T00:00:00","2021-10-06T00:00:00","2021-10-07T00:00:00","2021-10-08T00:00:00","2021-10-09T00:00:00","2021-10-10T00:00:00","2021-10-11T00:00:00","2021-10-12T00:00:00","2021-10-13T00:00:00","2021-10-14T00:00:00","2021-10-15T00:00:00","2021-10-16T00:00:00","2021-10-17T00:00:00","2021-10-18T00:00:00","2021-10-19T00:00:00","2021-10-20T00:00:00","2021-10-21T00:00:00","2021-10-22T00:00:00","2021-10-23T00:00:00","2021-10-24T00:00:00","2021-10-25T00:00:00","2021-10-26T00:00:00","2021-10-27T00:00:00","2021-10-28T00:00:00","2021-10-29T00:00:00","2021-10-30T00:00:00","2021-10-31T00:00:00","2021-11-01T00:00:00","2021-11-02T00:00:00","2021-11-03T00:00:00","2021-11-04T00:00:00","2021-11-05T00:00:00","2021-11-06T00:00:00","2021-11-07T00:00:00","2021-11-08T00:00:00","2021-11-09T00:00:00","2021-11-10T00:00:00","2021-11-11T00:00:00","202 ...

# %% [markdown]
# ## ADJUSTED THIS IS FOR PORTFOLIO OPTIMIZATION

# %%
adj_close_data = df["Adj Close"].values
adj_close_data = adj_close_data.reshape((-1))
look_back = 5
def predict(num_prediction, model):
    prediction_list = adj_close_data[-look_back:]
    
    for _ in range(num_prediction):
        x = prediction_list[-look_back:]
        x = x.reshape((1, look_back, 1))
        out = model.predict(x)[0][0]
        prediction_list = np.append(prediction_list, out)
    prediction_list = prediction_list[look_back-1:]
        
    return prediction_list
    
def predict_dates(num_prediction):
    last_date = df['Date'].values[-1]
    prediction_dates = pd.date_range(last_date, periods=num_prediction+1).tolist()
    return prediction_dates

num_prediction = 30
adj_forecast = predict(num_prediction, model)
forecast_dates = predict_dates(num_prediction)



#--------------------------

adj_close_train = adj_close_data[:split]
adj_close_test = adj_close_data[split:]

adj_close_train = adj_close_train.reshape((-1))
adj_close_test = adj_close_test.reshape((-1))
adj_prediction = adj_forecast.reshape((-1))

trace1 = go.Scatter(
    x = forecast_dates,
    y = adj_close_train,
    mode = 'lines',
    name = 'Data'
)
trace2 = go.Scatter(
    x = forecast_dates,
    y = adj_prediction,
    mode = 'lines',
    name = 'Prediction'
)
trace3 = go.Scatter(
    x = date_test,
    y = adj_close_test,
    mode='lines',
    name = 'Ground Truth'
)
layout = go.Layout(
    title = "Google Stock",
    xaxis = {'title' : "Date"},
    yaxis = {'title' : "Close"}
)
fig = go.Figure(data=[ trace2, trace3], layout=layout)
fig.show()
# Out:
# <div>                            <div id="af1d301e-4776-45f2-b526-b9bc6a2b35e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af1d301e-4776-45f2-b526-b9bc6a2b35e6")) {                    Plotly.newPlot(                        "af1d301e-4776-45f2-b526-b9bc6a2b35e6",                        [{"mode":"lines","name":"Prediction","x":["2021-12-31T00:00:00","2022-01-01T00:00:00","2022-01-02T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-08T00:00:00","2022-01-09T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-15T00:00:00","2022-01-16T00:00:00","2022-01-17T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-22T00:00:00","2022-01-23T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-29T00:00:00","2022-01-30T00:00:00"],"y":[85.472542,13.18931770324707,10.623525619506836,6.193710803985596,2.4701719284057617,2.2554683685302734,2.396646499633789,1.7536983489990234,0.9022254347801208,0.44923311471939087,0.3673224449157715,0.2844771444797516,0.17975223064422607,0.1181568130850792,0.09390030801296234,0.08443531394004822,0.07606963813304901,0.06941795349121094,0.06606984883546829,0.0646495372056961,0.06388267874717712,0.06330358237028122,0.06293488293886185,0.06275439262390137,0.06266658753156662,0.06261363625526428,0.0625782161951065,0.06255778670310974,0.0625474825501442,0.0625419169664383,0.06253853440284729],"type":"scatter"},{"mode":"lines","name":"Ground Truth","x":["2021-08-07T00:00:00","2021-08-08T00:00:00","2021-08-09T00:00:00","2021-08-10T00:00:00","2021-08-11T00:00:00","2021-08-12T00:00:00","2021-08-13T00:00:00","2021-08-14T00:00:00","2021-08-15T00:00:00","2021-08-16T00:00:00","2021-08-17T00:00:00","2021-08-18T00:00:00","2021-08-19T00:00:00","2021-08-20T00:00:00","2021-08-21T00:00:00","2021-08-22T00:00:00","2021-08-23T00:00:00","2021-08-24T00:00:00","2021-08-25T00:00:00","2021-08-26T00:00:00","2021-08-27T00:00:00","2021-08-28T00:00:00","2021-08-29T00:00:00","2021-08-30T00:00:00","2021-08-31T00:00:00","2021-09-01T00:00:00","2021-09-02T00:00:00","2021-09-03T00:00:00","2021-09-04T00:00:00","2021-09-05T00:00:00","2021-09-06T00:00:00","2021-09-07T00:00:00","2021-09-08T00:00:00","2021-09-09T00:00:00","2021-09-10T00:00:00","2021-09-11T00:00:00","2021-09-12T00:00:00","2021-09-13T00:00:00","2021-09-14T00:00:00","2021-09-15T00:00:00","2021-09-16T00:00:00","2021-09-17T00:00:00","2021-09-18T00:00:00","2021-09-19T00:00:00","2021-09-20T00:00:00","2021-09-21T00:00:00","2021-09-22T00:00:00","2021-09-23T00:00:00","2021-09-24T00:00:00","2021-09-25T00:00:00","2021-09-26T00:00:00","2021-09-27T00:00:00","2021-09-28T00:00:00","2021-09-29T00:00:00","2021-09-30T00:00:00","2021-10-01T00:00:00","2021-10-02T00:00:00","2021-10-03T00:00:00","2021-10-04T00:00:00","2021-10-05T00:00:00","2021-10-06T00:00:00","2021-10-07T00:00:00","2021-10-08T00:00:00","2021-10-09T00:00:00","2021-10-10T00:00:00","2021-10-11T00:00:00","2021-10-12T00:00:00","2021-10-13T00:00:00","2021-10-14T00:00:00","2021-10-15T00:00:00","2021-10-16T00:00:00","2021-10-17T00:00:00","2021-10-18T00:00:00","2021-10-19T00:00:00","2021-10-20T00:00:00","2021-10-21T00:00:00","2021-10-22T00:00:00","2021-10-23T00:00:00","2021-10-24T00:00:00","2021-10-25T00:00:00","2021-10-26T00:00:00","2021-10-27T00:00:00","2021-10-28T00:00:00","2021-10-29T00:00:00","2021-10-30T00:00:00","2021-10-31T00:00:00","2021-11-01T00:00:00","2021-11-02T00:00:00","2021-11-03T00:00:00","2021-11-04T00:00:00","2021-11-05T00:00:00","2021-11-06T00:00:00","2021-11-07T00:00:00","2021-11-08T00:00:00","2021-11-09T00:00: ...

# %% [markdown]
# ## ADDING ALL INFO INTO A FILE

# %%
#get all close prices values with predicted values (for protfolio prediction)
import datetime

indexes = pd.date_range(start='31/12/2021', end='1/30/2022')

newdf = pd.DataFrame(indexes, columns = ["Date"])
newdf["Close"] = forecast
newdf["Adj Close"] = adj_forecast
dffinal = df.loc[:,["Date" ,"Close","Adj Close"]]
dffinal = dffinal.append(newdf)
dffinal['Date'] = pd.to_datetime(dffinal['Date'])
dffinal
# Out:
#                           Date      Close  Adj Close
# 2020-01-01 00:00:00 2020-01-01   0.231019   0.231019
# 2020-01-02 00:00:00 2020-01-02   0.211493   0.211493
# 2020-01-03 00:00:00 2020-01-03   0.220498   0.220498
# 2020-01-04 00:00:00 2020-01-04   0.242335   0.242335
# 2020-01-05 00:00:00 2020-01-05   0.240061   0.240061
# ...                        ...        ...        ...
# 26                  2022-01-26  72.565170   0.062578
# 27                  2022-01-27  72.057182   0.062558
# 28                  2022-01-28  71.623596   0.062547
# 29                  2022-01-29  71.184097   0.062542
# 30                  2022-01-30  70.710365   0.062539
#
# [762 rows x 3 columns]

# %%
dffinal.to_csv("LUNApredict.csv", index = False)

# %% [markdown]
# ## PORTFOLIO OPTIMIZATION STATS

# %%
dffinal = pd.read_csv("ADApredict.csv")

# %%
dffinal.set_axis(dffinal['Date'], inplace=True)
dffinal.drop(columns=["Date"],inplace = True)

# %%
#this are the predicted valyes 

dffinal.tail(60)

# %%
test = pd.read_csv("AOA.csv")

# %%
test
