# %%
import pandas as pd
import numpy as np
import keras
import tensorflow as tf
from keras.preprocessing.sequence import TimeseriesGenerator
import plotly.graph_objs as go

# %%
filename = "VOO.csv"
df = pd.read_csv(filename)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1258 non-null   object
#  1   Open       1258 non-null   float64
#  2   High       1258 non-null   float64
#  3   Low        1258 non-null   float64
#  4   Close      1258 non-null   float64
#  5   Adj Close  1258 non-null   float64
#  6   Volume     1258 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 68.9+ KB
# None

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_axis(df['Date'], inplace=True)
df.drop(columns=['Open', 'High', 'Low', 'Volume'], inplace=True)

# %%
close_data = df['Close'].values
close_data = close_data.reshape((-1,1))

split_percent = 0.80
split = int(split_percent*len(close_data))

close_train = close_data[:split]
close_test = close_data[split:]

date_train = df['Date'][:split]
date_test = df['Date'][split:]

print(len(close_train))
print(len(close_test))
# Out:
# 1006
# 252

# %%
look_back = 10

train_generator = TimeseriesGenerator(close_train, close_train, length=look_back, batch_size=20)     
test_generator = TimeseriesGenerator(close_test, close_test, length=look_back, batch_size=1)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense

model = Sequential()
model.add(
    LSTM(units = 50,return_sequences = True,
        activation='relu',
        input_shape=(look_back,1))
)

model.add(
    LSTM(30,
        activation='relu',
        input_shape=(look_back,1), return_sequences = True)
)

model.add(
    LSTM(10,
        activation='relu',
        input_shape=(look_back,1))
)

model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

num_epochs = 100
model.fit(train_generator, epochs=num_epochs, verbose=1)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 4s 9ms/step - loss: 14851.7559
# Epoch 2/100
# 50/50 [==============================] - 0s 9ms/step - loss: 322.8733
# Epoch 3/100
# 50/50 [==============================] - 0s 8ms/step - loss: 77.9005
# Epoch 4/100
# 50/50 [==============================] - 0s 8ms/step - loss: 71.0486
# Epoch 5/100
# 50/50 [==============================] - 0s 9ms/step - loss: 74.0310
# Epoch 6/100
# 50/50 [==============================] - 0s 8ms/step - loss: 74.1096
# Epoch 7/100
# 50/50 [==============================] - 0s 9ms/step - loss: 63.6064
# Epoch 8/100
# 50/50 [==============================] - 0s 9ms/step - loss: 62.7791
# Epoch 9/100
# 50/50 [==============================] - 1s 10ms/step - loss: 66.0483
# Epoch 10/100
# 50/50 [==============================] - 0s 9ms/step - loss: 66.3309
# Epoch 11/100
# 50/50 [==============================] - 0s 9ms/step - loss: 64.6623
# Epoch 12/100
# 50/50 [==============================] - 0s 8ms/step - loss: 64.9353
# Epoch 13/100
# 50/50 [==============================] - 0s 9ms/step - loss: 60.6365
# Epoch 14/100
# 50/50 [==============================] - 0s 8ms/step - loss: 61.8768
# Epoch 15/100
# 50/50 [==============================] - 0s 9ms/step - loss: 61.5932
# Epoch 16/100
# 50/50 [==============================] - 0s 9ms/step - loss: 65.2578
# Epoch 17/100
# 50/50 [==============================] - 0s 9ms/step - loss: 55.0053
# Epoch 18/100
# 50/50 [==============================] - 0s 9ms/step - loss: 63.9965
# Epoch 19/100
# 50/50 [==============================] - 0s 9ms/step - loss: 52.9651
# Epoch 20/100
# 50/50 [==============================] - 0s 8ms/step - loss: 56.4449
# Epoch 21/100
# 50/50 [==============================] - 0s 8ms/step - loss: 54.0521
# Epoch 22/100
# 50/50 [==============================] - 0s 8ms/step - loss: 51.0490
# Epoch 23/100
# 50/50 [==============================] - 0s 8ms/step - loss: 47.1598
# Epoch 24/100
# 50/50 [==============================] - 0s 8ms/step - loss: 57.4895
# Epoch 25/100
# 50/50 [==============================] - 0s 8ms/step - loss: 53.0209
# Epoch 26/100
# 50/50 [==============================] - 0s 8ms/step - loss: 45.6586
# Epoch 27/100
# 50/50 [==============================] - 0s 8ms/step - loss: 47.8558
# Epoch 28/100
# 50/50 [==============================] - 0s 8ms/step - loss: 39.0641
# Epoch 29/100
# 50/50 [==============================] - 0s 8ms/step - loss: 48.8114
# Epoch 30/100
# 50/50 [==============================] - 0s 8ms/step - loss: 53.9254
# Epoch 31/100
# 50/50 [==============================] - 0s 8ms/step - loss: 68.6388
# Epoch 32/100
# 50/50 [==============================] - 0s 8ms/step - loss: 77.5272
# Epoch 33/100
# 50/50 [==============================] - 0s 9ms/step - loss: 55.9007
# Epoch 34/100
# 50/50 [==============================] - 0s 8ms/step - loss: 49.7490
# Epoch 35/100
# 50/50 [==============================] - 0s 8ms/step - loss: 47.9007
# Epoch 36/100
# 50/50 [==============================] - 0s 9ms/step - loss: 47.1983
# Epoch 37/100
# 50/50 [==============================] - 0s 10ms/step - loss: 53.1688
# Epoch 38/100
# 50/50 [==============================] - 0s 9ms/step - loss: 48.3962
# Epoch 39/100
# 50/50 [==============================] - 0s 8ms/step - loss: 58.5185
# Epoch 40/100
# 50/50 [==============================] - 0s 9ms/step - loss: 45.9296
# Epoch 41/100
# 50/50 [==============================] - 0s 9ms/step - loss: 42.2723
# Epoch 42/100
# 50/50 [==============================] - 0s 9ms/step - loss: 46.8752
# Epoch 43/100
# 50/50 [==============================] - 0s 9ms/step - loss: 55.6678
# Epoch 44/100
# 50/50 [==============================] - 0s 9ms/step - loss: 55.9330
# Epoch 45/100
# 50/50 [==============================] - 0s 9ms/step - loss: 46.7381
# Epoch 46/100
# 50/50 [==============================] - 0s 9ms/step - loss: 48.5489
# Epoch 47/100
# 50/50 [==============================] - 0s 9ms/step - loss: 46.9358
# Epoch 48/100
# 50/50 [==============================] - 0s 9ms/step - loss: 48.3459
# Epoch 49/100
# 50/50 [==============================] - 1s 10ms/step - loss: 41.6532
# Epoch 50/100
# 50/50 [==============================] - 1s 10ms/step - loss: 37.0933
# Epoch 51/100
# 50/50 [==============================] - 1s 13ms/step - loss: 167.1883
# Epoch 52/100
# 50/50 [==============================] - 1s 14ms/step - loss: 99.6743
# Epoch 53/100
# 50/50 [==============================] - 1s 13ms/step - loss: 64.9914
# Epoch 54/100
# 50/50 [==============================] - 1s 13ms/step - loss: 65.2194
# Epoch 55/100
# 50/50 [==============================] - 1s 14ms/step - loss: 64.1091
# Epoch 56/100
# 50/50 [==============================] - 1s 13ms/step - loss: 70.3479
# Epoch 57/100
# 50/50 [==============================] - 1s 13ms/step - loss: 98.1369
# Epoch 58/100
# 50/50 [==============================] - 1s 13ms/step - loss: 64.3899
# Epoch 59/100
# 50/50 [==============================] - 1s 14ms/step - loss: 57.4025
# Epoch 60/100
# 50/50 [==============================] - 1s 13ms/step - loss: 67.5597
# Epoch 61/100
# 50/50 [==============================] - 1s 12ms/step - loss: 61.4242
# Epoch 62/100
# 50/50 [==============================] - 1s 12ms/step - loss: 52.5222
# Epoch 63/100
# 50/50 [==============================] - 1s 11ms/step - loss: 59.2552
# Epoch 64/100
# 50/50 [==============================] - 1s 12ms/step - loss: 58.8002
# Epoch 65/100
# 50/50 [==============================] - 1s 13ms/step - loss: 57.7018
# Epoch 66/100
# 50/50 [==============================] - 1s 12ms/step - loss: 52.4688
# Epoch 67/100
# 50/50 [==============================] - 1s 14ms/step - loss: 45.2388
# Epoch 68/100
# 50/50 [==============================] - 1s 12ms/step - loss: 67.9495
# Epoch 69/100
# 50/50 [==============================] - 1s 13ms/step - loss: 59.2755
# Epoch 70/100
# 50/50 [==============================] - 1s 13ms/step - loss: 63.0127
# Epoch 71/100
# 50/50 [==============================] - 1s 12ms/step - loss: 60.8362
# Epoch 72/100
# 50/50 [==============================] - 1s 12ms/step - loss: 53.4731
# Epoch 73/100
# 50/50 [==============================] - 1s 13ms/step - loss: 56.7379
# Epoch 74/100
# 50/50 [==============================] - 1s 13ms/step - loss: 64.0922
# Epoch 75/100
# 50/50 [==============================] - 1s 11ms/step - loss: 65.7014
# Epoch 76/100
# 50/50 [==============================] - 1s 11ms/step - loss: 60.9700
# Epoch 77/100
# 50/50 [==============================] - 1s 11ms/step - loss: 72.3521
# Epoch 78/100
# 50/50 [==============================] - 1s 13ms/step - loss: 53.7226
# Epoch 79/100
# 50/50 [==============================] - 1s 13ms/step - loss: 55.5717
# Epoch 80/100
# 50/50 [==============================] - 1s 12ms/step - loss: 50.8930
# Epoch 81/100
# 50/50 [==============================] - 1s 14ms/step - loss: 50.5805
# Epoch 82/100
# 50/50 [==============================] - 1s 14ms/step - loss: 58.3154
# Epoch 83/100
# 50/50 [==============================] - 1s 13ms/step - loss: 58.9366
# Epoch 84/100
# 50/50 [==============================] - 1s 13ms/step - loss: 46.7303
# Epoch 85/100
# 50/50 [==============================] - 1s 11ms/step - loss: 51.5455
# Epoch 86/100
# 50/50 [==============================] - 1s 11ms/step - loss: 60.5474
# Epoch 87/100
# 50/50 [==============================] - 1s 11ms/step - loss: 55.5485
# Epoch 88/100
# 50/50 [==============================] - 1s 11ms/step - loss: 55.4162
# Epoch 89/100
# 50/50 [==============================] - 1s 11ms/step - loss: 62.9179
# Epoch 90/100
# 50/50 [==============================] - 1s 11ms/step - loss: 56.2867
# Epoch 91/100
# 50/50 [==============================] - 1s 11ms/step - loss: 58.5332
# Epoch 92/100
# 50/50 [==============================] - 0s 9ms/step - loss: 54.0978
# Epoch 93/100
# 50/50 [==============================] - 0s 8ms/step - loss: 55.6927
# Epoch 94/100
# 50/50 [==============================] - 1s 11ms/step - loss: 50.8705
# Epoch 95/100
# 50/50 [==============================] - 0s 10ms/step - loss: 69.2301
# Epoch 96/100
# 50/50 [==============================] - 0s 9ms/step - loss: 53.0658
# Epoch 97/100
# 50/50 [==============================] - 1s 10ms/step - loss: 45.8594
# Epoch 98/100
# 50/50 [==============================] - 0s 9ms/step - loss: 59.3780
# Epoch 99/100
# 50/50 [==============================] - 1s 10ms/step - loss: 50.2563
# Epoch 100/100
# 50/50 [==============================] - 1s 10ms/step - loss: 64.3926

# %%
prediction = model.predict(test_generator)

close_train = close_train.reshape((-1))
close_test = close_test.reshape((-1))
prediction = prediction.reshape((-1))

trace1 = go.Scatter(
    x = date_train,
    y = close_train,
    mode = 'lines',
    name = 'Data'
)
trace2 = go.Scatter(
    x = date_test,
    y = prediction,
    mode = 'lines',
    name = 'Prediction'
)
trace3 = go.Scatter(
    x = date_test,
    y = close_test,
    mode='lines',
    name = 'Ground Truth'
)
layout = go.Layout(
    title = "Google Stock",
    xaxis = {'title' : "Date"},
    yaxis = {'title' : "Close"}
)
fig = go.Figure(data=[trace1, trace2, trace3], layout=layout)
fig.show()
# Out:
# <div>                            <div id="5a9f7cc7-8a99-4f66-b149-8615ae25ce40" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a9f7cc7-8a99-4f66-b149-8615ae25ce40")) {                    Plotly.newPlot(                        "5a9f7cc7-8a99-4f66-b149-8615ae25ce40",                        [{"mode":"lines","name":"Data","x":["2017-01-03T00:00:00","2017-01-04T00:00:00","2017-01-05T00:00:00","2017-01-06T00:00:00","2017-01-09T00:00:00","2017-01-10T00:00:00","2017-01-11T00:00:00","2017-01-12T00:00:00","2017-01-13T00:00:00","2017-01-17T00:00:00","2017-01-18T00:00:00","2017-01-19T00:00:00","2017-01-20T00:00:00","2017-01-23T00:00:00","2017-01-24T00:00:00","2017-01-25T00:00:00","2017-01-26T00:00:00","2017-01-27T00:00:00","2017-01-30T00:00:00","2017-01-31T00:00:00","2017-02-01T00:00:00","2017-02-02T00:00:00","2017-02-03T00:00:00","2017-02-06T00:00:00","2017-02-07T00:00:00","2017-02-08T00:00:00","2017-02-09T00:00:00","2017-02-10T00:00:00","2017-02-13T00:00:00","2017-02-14T00:00:00","2017-02-15T00:00:00","2017-02-16T00:00:00","2017-02-17T00:00:00","2017-02-21T00:00:00","2017-02-22T00:00:00","2017-02-23T00:00:00","2017-02-24T00:00:00","2017-02-27T00:00:00","2017-02-28T00:00:00","2017-03-01T00:00:00","2017-03-02T00:00:00","2017-03-03T00:00:00","2017-03-06T00:00:00","2017-03-07T00:00:00","2017-03-08T00:00:00","2017-03-09T00:00:00","2017-03-10T00:00:00","2017-03-13T00:00:00","2017-03-14T00:00:00","2017-03-15T00:00:00","2017-03-16T00:00:00","2017-03-17T00:00:00","2017-03-20T00:00:00","2017-03-21T00:00:00","2017-03-22T00:00:00","2017-03-23T00:00:00","2017-03-24T00:00:00","2017-03-27T00:00:00","2017-03-28T00:00:00","2017-03-29T00:00:00","2017-03-30T00:00:00","2017-03-31T00:00:00","2017-04-03T00:00:00","2017-04-04T00:00:00","2017-04-05T00:00:00","2017-04-06T00:00:00","2017-04-07T00:00:00","2017-04-10T00:00:00","2017-04-11T00:00:00","2017-04-12T00:00:00","2017-04-13T00:00:00","2017-04-17T00:00:00","2017-04-18T00:00:00","2017-04-19T00:00:00","2017-04-20T00:00:00","2017-04-21T00:00:00","2017-04-24T00:00:00","2017-04-25T00:00:00","2017-04-26T00:00:00","2017-04-27T00:00:00","2017-04-28T00:00:00","2017-05-01T00:00:00","2017-05-02T00:00:00","2017-05-03T00:00:00","2017-05-04T00:00:00","2017-05-05T00:00:00","2017-05-08T00:00:00","2017-05-09T00:00:00","2017-05-10T00:00:00","2017-05-11T00:00:00","2017-05-12T00:00:00","2017-05-15T00:00:00","2017-05-16T00:00:00","2017-05-17T00:00:00","2017-05-18T00:00:00","2017-05-19T00:00:00","2017-05-22T00:00:00","2017-05-23T00:00:00","2017-05-24T00:00:00","2017-05-25T00:00:00","2017-05-26T00:00:00","2017-05-30T00:00:00","2017-05-31T00:00:00","2017-06-01T00:00:00","2017-06-02T00:00:00","2017-06-05T00:00:00","2017-06-06T00:00:00","2017-06-07T00:00:00","2017-06-08T00:00:00","2017-06-09T00:00:00","2017-06-12T00:00:00","2017-06-13T00:00:00","2017-06-14T00:00:00","2017-06-15T00:00:00","2017-06-16T00:00:00","2017-06-19T00:00:00","2017-06-20T00:00:00","2017-06-21T00:00:00","2017-06-22T00:00:00","2017-06-23T00:00:00","2017-06-26T00:00:00","2017-06-27T00:00:00","2017-06-28T00:00:00","2017-06-29T00:00:00","2017-06-30T00:00:00","2017-07-03T00:00:00","2017-07-05T00:00:00","2017-07-06T00:00:00","2017-07-07T00:00:00","2017-07-10T00:00:00","2017-07-11T00:00:00","2017-07-12T00:00:00","2017-07-13T00:00:00","2017-07-14T00:00:00","2017-07-17T00:00:00","2017-07-18T00:00:00","2017-07-19T00:00:00","2017-07-20T00:00:00","2017-07-21T00:00:00","2017-07-24T00:00:00","2017-07-25T00:00:00","2017-07-26T00:00:00","2017-07-27T00:00:00","2017-07-28T00:00:00","2017-07-31T00:00:00","2017-08-01T00:00:00","2017-08-02T00:00:00","2017-08-03T00:00:00","2017-08-04T00:00:00","2017-08-07T00:00:00","2017-08-08T00:00:00","2017-08-09T00:00:00","2017-08-10T00:00:00","2017-08-11T00:00:00","2017-08-14T00:00:00","2017-08-15T00:00:00","2 ...

# %%
close_data = close_data.reshape((-1))
look_back = 10
def predict(num_prediction, model):
    prediction_list = close_data[-look_back:]
    
    for _ in range(num_prediction):
        x = prediction_list[-look_back:]
        x = x.reshape((1, look_back, 1))
        out = model.predict(x)[0][0]
        prediction_list = np.append(prediction_list, out)
    prediction_list = prediction_list[look_back-1:]
        
    return prediction_list
    
def predict_dates(num_prediction):
    last_date = df['Date'].values[-1]
    prediction_dates = pd.date_range(last_date, periods=num_prediction+1).tolist()
    return prediction_dates

num_prediction = 30
forecast = predict(num_prediction, model)
forecast_dates = predict_dates(num_prediction)

# %%
close_train = close_train.reshape((-1))
close_test = close_test.reshape((-1))
prediction = forecast.reshape((-1))

trace1 = go.Scatter(
    x = forecast_dates,
    y = close_train,
    mode = 'lines',
    name = 'Data'
)
trace2 = go.Scatter(
    x = forecast_dates,
    y = prediction,
    mode = 'lines',
    name = 'Prediction'
)
trace3 = go.Scatter(
    x = date_test,
    y = close_test,
    mode='lines',
    name = 'Ground Truth'
)
layout = go.Layout(
    title = "Google Stock",
    xaxis = {'title' : "Date"},
    yaxis = {'title' : "Close"}
)
fig = go.Figure(data=[trace2, trace3], layout=layout)
fig.show()
# Out:
# <div>                            <div id="afdb9504-257f-4d88-bc65-de67dbabd3f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("afdb9504-257f-4d88-bc65-de67dbabd3f5")) {                    Plotly.newPlot(                        "afdb9504-257f-4d88-bc65-de67dbabd3f5",                        [{"mode":"lines","name":"Prediction","x":["2021-12-30T00:00:00","2021-12-31T00:00:00","2022-01-01T00:00:00","2022-01-02T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-08T00:00:00","2022-01-09T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-15T00:00:00","2022-01-16T00:00:00","2022-01-17T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-22T00:00:00","2022-01-23T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-29T00:00:00"],"y":[437.769989,414.92572021484375,414.171630859375,395.1810302734375,407.95697021484375,399.9385681152344,387.03912353515625,390.586669921875,401.0623474121094,395.3323059082031,401.6138916015625,393.8641357421875,398.37872314453125,392.4950256347656,381.7484130859375,387.0753173828125,363.60308837890625,387.0775146484375,367.6720886230469,380.3048095703125,365.6453857421875,354.23724365234375,366.8940734863281,343.7945556640625,365.4815368652344,342.03753662109375,359.5562744140625,338.486572265625,330.638671875,332.1796569824219,321.0491638183594],"type":"scatter"},{"mode":"lines","name":"Ground Truth","x":["2020-12-31T00:00:00","2021-01-04T00:00:00","2021-01-05T00:00:00","2021-01-06T00:00:00","2021-01-07T00:00:00","2021-01-08T00:00:00","2021-01-11T00:00:00","2021-01-12T00:00:00","2021-01-13T00:00:00","2021-01-14T00:00:00","2021-01-15T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-25T00:00:00","2021-01-26T00:00:00","2021-01-27T00:00:00","2021-01-28T00:00:00","2021-01-29T00:00:00","2021-02-01T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-04T00:00:00","2021-02-05T00:00:00","2021-02-08T00:00:00","2021-02-09T00:00:00","2021-02-10T00:00:00","2021-02-11T00:00:00","2021-02-12T00:00:00","2021-02-16T00:00:00","2021-02-17T00:00:00","2021-02-18T00:00:00","2021-02-19T00:00:00","2021-02-22T00:00:00","2021-02-23T00:00:00","2021-02-24T00:00:00","2021-02-25T00:00:00","2021-02-26T00:00:00","2021-03-01T00:00:00","2021-03-02T00:00:00","2021-03-03T00:00:00","2021-03-04T00:00:00","2021-03-05T00:00:00","2021-03-08T00:00:00","2021-03-09T00:00:00","2021-03-10T00:00:00","2021-03-11T00:00:00","2021-03-12T00:00:00","2021-03-15T00:00:00","2021-03-16T00:00:00","2021-03-17T00:00:00","2021-03-18T00:00:00","2021-03-19T00:00:00","2021-03-22T00:00:00","2021-03-23T00:00:00","2021-03-24T00:00:00","2021-03-25T00:00:00","2021-03-26T00:00:00","2021-03-29T00:00:00","2021-03-30T00:00:00","2021-03-31T00:00:00","2021-04-01T00:00:00","2021-04-05T00:00:00","2021-04-06T00:00:00","2021-04-07T00:00:00","2021-04-08T00:00:00","2021-04-09T00:00:00","2021-04-12T00:00:00","2021-04-13T00:00:00","2021-04-14T00:00:00","2021-04-15T00:00:00","2021-04-16T00:00:00","2021-04-19T00:00:00","2021-04-20T00:00:00","2021-04-21T00:00:00","2021-04-22T00:00:00","2021-04-23T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-28T00:00:00","2021-04-29T00:00:00","2021-04-30T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-05T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-10T00:00:00","2021-05-11T00:00:00","2021-05-12T00:00:00","2021-05-13T00:00:00","2021-05-14T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-19T00:00:00","2021-05-20T00: ...

# %% [markdown]
# ## ADJUSTED THIS IS FOR PORTFOLIO OPTIMIZATION

# %%
adj_close_data = df["Adj Close"].values
adj_close_data = adj_close_data.reshape((-1))
look_back = 10
def predict(num_prediction, model):
    prediction_list = adj_close_data[-look_back:]
    
    for _ in range(num_prediction):
        x = prediction_list[-look_back:]
        x = x.reshape((1, look_back, 1))
        out = model.predict(x)[0][0]
        prediction_list = np.append(prediction_list, out)
    prediction_list = prediction_list[look_back-1:]
        
    return prediction_list
    
def predict_dates(num_prediction):
    last_date = df['Date'].values[-1]
    prediction_dates = pd.date_range(last_date, periods=num_prediction+1).tolist()
    return prediction_dates

num_prediction = 30
adj_forecast = predict(num_prediction, model)
forecast_dates = predict_dates(num_prediction)



#--------------------------

adj_close_train = adj_close_data[:split]
adj_close_test = adj_close_data[split:]

adj_close_train = adj_close_train.reshape((-1))
adj_close_test = adj_close_test.reshape((-1))
adj_prediction = adj_forecast.reshape((-1))

trace1 = go.Scatter(
    x = forecast_dates,
    y = adj_close_train,
    mode = 'lines',
    name = 'Data'
)
trace2 = go.Scatter(
    x = forecast_dates,
    y = adj_prediction,
    mode = 'lines',
    name = 'Prediction'
)
trace3 = go.Scatter(
    x = date_test,
    y = adj_close_test,
    mode='lines',
    name = 'Ground Truth'
)
layout = go.Layout(
    title = "Google Stock",
    xaxis = {'title' : "Date"},
    yaxis = {'title' : "Close"}
)
fig = go.Figure(data=[ trace2, trace3], layout=layout)
fig.show()
# Out:
# <div>                            <div id="12e8eadf-39e7-435e-abf0-5b69a315b6ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12e8eadf-39e7-435e-abf0-5b69a315b6ec")) {                    Plotly.newPlot(                        "12e8eadf-39e7-435e-abf0-5b69a315b6ec",                        [{"mode":"lines","name":"Prediction","x":["2021-12-30T00:00:00","2021-12-31T00:00:00","2022-01-01T00:00:00","2022-01-02T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-08T00:00:00","2022-01-09T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-15T00:00:00","2022-01-16T00:00:00","2022-01-17T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-22T00:00:00","2022-01-23T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-29T00:00:00"],"y":[436.300537,429.41253662109375,429.91229248046875,431.5016174316406,434.3944091796875,436.2445373535156,437.4042053222656,438.3673095703125,438.0374450683594,437.5262451171875,436.7969055175781,436.33404541015625,437.4579772949219,438.6888427734375,439.8044738769531,440.49017333984375,440.8897399902344,441.11181640625,441.1356201171875,441.23370361328125,441.5083312988281,442.0462646484375,442.8227233886719,443.50152587890625,444.03961181640625,444.43719482421875,444.7640075683594,445.0728759765625,445.4014892578125,445.8073425292969,446.29461669921875],"type":"scatter"},{"mode":"lines","name":"Ground Truth","x":["2020-12-31T00:00:00","2021-01-04T00:00:00","2021-01-05T00:00:00","2021-01-06T00:00:00","2021-01-07T00:00:00","2021-01-08T00:00:00","2021-01-11T00:00:00","2021-01-12T00:00:00","2021-01-13T00:00:00","2021-01-14T00:00:00","2021-01-15T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-25T00:00:00","2021-01-26T00:00:00","2021-01-27T00:00:00","2021-01-28T00:00:00","2021-01-29T00:00:00","2021-02-01T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-04T00:00:00","2021-02-05T00:00:00","2021-02-08T00:00:00","2021-02-09T00:00:00","2021-02-10T00:00:00","2021-02-11T00:00:00","2021-02-12T00:00:00","2021-02-16T00:00:00","2021-02-17T00:00:00","2021-02-18T00:00:00","2021-02-19T00:00:00","2021-02-22T00:00:00","2021-02-23T00:00:00","2021-02-24T00:00:00","2021-02-25T00:00:00","2021-02-26T00:00:00","2021-03-01T00:00:00","2021-03-02T00:00:00","2021-03-03T00:00:00","2021-03-04T00:00:00","2021-03-05T00:00:00","2021-03-08T00:00:00","2021-03-09T00:00:00","2021-03-10T00:00:00","2021-03-11T00:00:00","2021-03-12T00:00:00","2021-03-15T00:00:00","2021-03-16T00:00:00","2021-03-17T00:00:00","2021-03-18T00:00:00","2021-03-19T00:00:00","2021-03-22T00:00:00","2021-03-23T00:00:00","2021-03-24T00:00:00","2021-03-25T00:00:00","2021-03-26T00:00:00","2021-03-29T00:00:00","2021-03-30T00:00:00","2021-03-31T00:00:00","2021-04-01T00:00:00","2021-04-05T00:00:00","2021-04-06T00:00:00","2021-04-07T00:00:00","2021-04-08T00:00:00","2021-04-09T00:00:00","2021-04-12T00:00:00","2021-04-13T00:00:00","2021-04-14T00:00:00","2021-04-15T00:00:00","2021-04-16T00:00:00","2021-04-19T00:00:00","2021-04-20T00:00:00","2021-04-21T00:00:00","2021-04-22T00:00:00","2021-04-23T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-28T00:00:00","2021-04-29T00:00:00","2021-04-30T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-05T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-10T00:00:00","2021-05-11T00:00:00","2021-05-12T00:00:00","2021-05-13T00:00:00","2021-05-14T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-19T00:00:00","2021-05 ...

# %% [markdown]
# ## ADDING ALL INFO INTO A FILE

# %%
#get all close prices values with predicted values (for protfolio prediction)
import datetime

indexes = pd.date_range(start='31/12/2021', end='1/30/2022')

newdf = pd.DataFrame(indexes, columns = ["Date"])
newdf["Close"] = forecast
newdf["Adj Close"] = adj_forecast
dffinal = df.loc[:,["Date" ,"Close","Adj Close"]]
dffinal = dffinal.append(newdf)
dffinal['Date'] = pd.to_datetime(dffinal['Date'])
dffinal
# Out:
#                           Date       Close   Adj Close
# 2017-01-03 00:00:00 2017-01-03  206.740005  188.193024
# 2017-01-04 00:00:00 2017-01-04  207.960007  189.303604
# 2017-01-05 00:00:00 2017-01-05  207.800003  189.157974
# 2017-01-06 00:00:00 2017-01-06  208.610001  189.895294
# 2017-01-09 00:00:00 2017-01-09  207.949997  189.294510
# ...                        ...         ...         ...
# 26                  2022-01-26  446.477661  444.764008
# 27                  2022-01-27  446.792206  445.072876
# 28                  2022-01-28  447.124725  445.401489
# 29                  2022-01-29  447.530914  445.807343
# 30                  2022-01-30  448.013489  446.294617
#
# [1289 rows x 3 columns]

# %%
dffinal.to_csv("voopredict.csv", index = False)

# %% [markdown]
# ## PORTFOLIO OPTIMIZATION STATS

# %%
dffinal = pd.read_csv("voopredict.csv")

# %%
dffinal.set_axis(dffinal['Date'], inplace=True)
dffinal.drop(columns=["Date"],inplace = True)

# %%
#this are the predicted valyes 

dffinal.tail(60)
